# %%
# Import necessary libraries
import tensorflow as tf  # Import TensorFlow for deep learning operations
import os               # Import OS for file and directory operations
import numpy as np     # Import NumPy for numerical operations
from matplotlib import pyplot as plt  # Import Matplotlib for data visualization

# Load image data from the 'data' directory using TensorFlow's image_dataset_from_directory function
data = tf.keras.utils.image_dataset_from_directory('augmented')

# Create an iterator to iterate through the data
data_iterator = data.as_numpy_iterator()

# Get a batch of data from the iterator
batch = data_iterator.next()

# Check the length of the batch
len(batch)

# Display the labels of the batch (0 for fake, 1 for real)
batch[1]

# Create a figure with 8 subplots for displaying sample images
fig, ax = plt.subplots(ncols=8, figsize=(20, 20))

# Loop through the first 8 images in the batch and display them along with their labels
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
# Out:
# Found 368 files belonging to 2 classes.

# %%
# Scale the image data by dividing it by 255 to normalize pixel values
scaled = batch[0]
data = data.map(lambda x, y: (x / 255, y))

# Check the maximum pixel value in the normalized data
data.as_numpy_iterator().next()[0].max()

# Get the total number of samples in the dataset
len(data)

# Split the dataset into training, validation, and test sets based on specified proportions
train_size = int(len(data) * 0.7) + 1  # 70% for training
val_size = int(len(data) * 0.2)        # 20% for validation
test_size = int(len(data) * 0.1)       # 10% for testing

# Check the sum of sizes for verification
val_size + train_size + test_size

# Create training, validation, and test datasets using the split sizes
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size + val_size).take(test_size)

# %%
def create_model():
    from tensorflow.keras.applications import ResNet50
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Flatten

    # Load the ResNet50 model with weights pre-trained on ImageNet
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

    # Freeze the base model layers to prevent training on them
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom layers on top of the pre-trained model
    model = Sequential()
    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
    return model

# %%
model = create_model() 
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 8, 8, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      33,554,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,142,657 (217.98 MB)
#  Trainable params: 33,554,945 (128.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.5962 - loss: 11.6006 - val_accuracy: 0.5156 - val_loss: 10.2798
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.6692 - loss: 5.0722 - val_accuracy: 0.2812 - val_loss: 3.0811
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5399 - loss: 1.6061 - val_accuracy: 0.8125 - val_loss: 0.4712
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.7716 - loss: 0.5922 - val_accuracy: 0.8281 - val_loss: 0.5071
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8297 - loss: 0.4478 - val_accuracy: 0.8438 - val_loss: 0.3974
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.8576 - loss: 0.3375 - val_accuracy: 0.9219 - val_loss: 0.1853
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.8691 - loss: 0.3198 - val_accuracy: 0.8906 - val_loss: 0.3060
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.8826 - loss: 0.2829 - val_accuracy: 0.8438 - val_loss: 0.3968
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.8848 - loss: 0.2733 - val_accuracy: 0.9219 - val_loss: 0.1986
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9144 - loss: 0.1976 - val_accuracy: 0.9531 - val_loss: 0.1538

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='red', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# Function to calculate precision, recall, f1 score, and accuracy
def evaluate_model(model, test_data):
    # Predict on the test data
    y_pred = []
    y_true = []
    
    for images, labels in test_data:
        preds = model.predict(images)
        y_pred.extend(np.round(preds).flatten())  # Round the predictions to the nearest integer (0 or 1)
        y_true.extend(labels.numpy().flatten())  # Flatten the true labels

    # Calculate precision, recall, f1 score, and accuracy
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'Accuracy: {accuracy:.4f}')
    
    # Return the predictions and true labels for further use
    return y_true, y_pred

# Evaluate the model
y_true, y_pred = evaluate_model(model, test)

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Fake', 'Original'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Precision: 0.8889
# Recall: 0.8000
# F1 Score: 0.8421
# Accuracy: 0.8125

# %%
import tensorflow as tf
model = create_model()
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open("model.tflite", 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ASUS\AppData\Local\Temp\tmpt_ekucjo\assets
# INFO:tensorflow:Assets written to: C:\Users\ASUS\AppData\Local\Temp\tmpt_ekucjo\assets
# Saved artifact at 'C:\Users\ASUS\AppData\Local\Temp\tmpt_ekucjo'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_545')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1541517933840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517933264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517934416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517934224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517933648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517933072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517929616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517928464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517928080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517930000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517929232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517928272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517927312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517926160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517925776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517927696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517926928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517925968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517925008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517923856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517930768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517930384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517932304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517931536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517930576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517923472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517925392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517924624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517923664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517923088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541517924240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332222416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332223184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332222800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332225104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393761104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393760336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393761296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393760528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393762064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393763216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393763600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393761680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393762448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393763408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541086133136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393765328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541332236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393765712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393764752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393765136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393765520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393762832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393767824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393768208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393767440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393766096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393768016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393768976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393770128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393770512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393768592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393769360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393770320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393771280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393772432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393772816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393770896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393771664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393772624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393773584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393774736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393775120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393773200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393773968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393774928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393774352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393775888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518590800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518590032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541393776272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518590224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518591568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518592720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518593104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518591184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518591952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518592912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518593872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518595408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518594256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518595216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518596176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518597328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518597712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518595792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518596560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518597520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518598480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518599632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518600016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518598096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518598864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518599824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518602704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518604432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518605392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518394384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518605776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518393616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518394768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518395920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518601936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518600400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518601168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518396304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518394192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518395152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518396112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518398224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518398608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518396688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518398416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518400528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518400912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518398992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518399760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518400720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518401680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518402832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518403216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518401296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518402064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518403024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518403984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518405136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518405520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518403600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518404368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518405328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518407440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518407824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518405904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518406672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518407632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518408592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518655568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518656336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518656720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518657872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518658256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518655760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518657104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518658064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518660176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518658640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518659408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518660368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518662480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518660944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518661712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518662672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518663632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518664784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518665168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518663248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518664016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518664976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518665936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518667088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518667472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518665552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518667280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518668240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518669392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518669776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518667856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518668624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518669584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518670544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518670160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146919952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518655952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541518671696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146919760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146921104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146921488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146919568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146920336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146921296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146922256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146923408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146923792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146921872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146923600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146926864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146928016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146928400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146927248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146928208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146929168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146930320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146930704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146928784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146929552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146930512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146931472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146932624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146924560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146925712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146926096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146924176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146924944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146925904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146933008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146931088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146931856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146932816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146933776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146934736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146934928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146935952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146918992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146935120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146936144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146937296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146935568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146936528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146937488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146938448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146939600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146939984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146938064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146938832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146939792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146941904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146942288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146940368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146941136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146942096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146944208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146944592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146942672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146943440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146944400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146946512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146945744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146946704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146947664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146949008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146948624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1541146949776: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
model = create_model()
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])


# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save('my_model.h5')
# Out:
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 59s 5s/step - accuracy: 0.5058 - loss: 20.6451 - val_accuracy: 0.6562 - val_loss: 7.3554
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.7270 - loss: 4.0410 - val_accuracy: 0.7969 - val_loss: 5.1839
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step - accuracy: 0.8057 - loss: 2.5858 - val_accuracy: 0.8281 - val_loss: 1.8468
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8116 - loss: 1.7385 - val_accuracy: 0.8750 - val_loss: 0.9911
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8089 - loss: 1.0173 - val_accuracy: 0.8750 - val_loss: 0.4209
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8884 - loss: 0.5070 - val_accuracy: 0.8438 - val_loss: 0.4758
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step - accuracy: 0.8105 - loss: 0.6207 - val_accuracy: 0.8438 - val_loss: 0.3468
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step - accuracy: 0.9058 - loss: 0.3043 - val_accuracy: 0.8906 - val_loss: 0.3347
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8781 - loss: 0.3124 - val_accuracy: 0.8438 - val_loss: 0.3766
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step - accuracy: 0.8889 - loss: 0.3032 - val_accuracy: 0.9688 - val_loss: 0.0603
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
